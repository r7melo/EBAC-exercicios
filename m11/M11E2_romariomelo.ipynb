# %% [markdown]
# ## Árvores de regressão - exercícios 02
#
# Este exercício será uma continuação do anterior, mesma base, mesmas variáveis - vamos tentar buscar a 'melhor árvore'.

# %% [markdown]
# *Atenção - Utilizar a base de dados em anexo que é a mesma base que utilizamos na atividade anterior! A base Boston, assim como para a primeira atividade foi descontinuada e não deve ser utilizada*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


boston = pd.read_csv('boston.csv')
boston = boston.drop(columns='b')
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# 3       18.7   2.94  33.4
# 4       18.7   5.33  36.2
# ..       ...    ...   ...
# 501     21.0   9.67  22.4
# 502     21.0   9.08  20.6
# 503     21.0   5.64  23.9
# 504     21.0   6.48  22.0
# 505     21.0   7.88  11.9
#
# [506 rows x 13 columns]

# %% [markdown]
# ### 1. Execute os passos do exercício anterior, até que você tenha uma árvore de regressão predizendo o valor do imóvel na base de treinamento.

# %%
colunas_correlacionadas = ['rm', 'nox', 'indus', 'lstat', 'tax', 'ptratio', 'medv']
boston_df = boston[colunas_correlacionadas]
boston_df
# Out:
#         rm    nox  indus  lstat  tax  ptratio  medv
# 0    6.575  0.538   2.31   4.98  296     15.3  24.0
# 1    6.421  0.469   7.07   9.14  242     17.8  21.6
# 2    7.185  0.469   7.07   4.03  242     17.8  34.7
# 3    6.998  0.458   2.18   2.94  222     18.7  33.4
# 4    7.147  0.458   2.18   5.33  222     18.7  36.2
# ..     ...    ...    ...    ...  ...      ...   ...
# 501  6.593  0.573  11.93   9.67  273     21.0  22.4
# 502  6.120  0.573  11.93   9.08  273     21.0  20.6
# 503  6.976  0.573  11.93   5.64  273     21.0  23.9
# 504  6.794  0.573  11.93   6.48  273     21.0  22.0
# 505  6.030  0.573  11.93   7.88  273     21.0  11.9
#
# [506 rows x 7 columns]

# %%
x = boston_df.drop(columns=['medv'])
x.head()
# Out:
#       rm    nox  indus  lstat  tax  ptratio
# 0  6.575  0.538   2.31   4.98  296     15.3
# 1  6.421  0.469   7.07   9.14  242     17.8
# 2  7.185  0.469   7.07   4.03  242     17.8
# 3  6.998  0.458   2.18   2.94  222     18.7
# 4  7.147  0.458   2.18   5.33  222     18.7

# %%
y = boston_df['medv']
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: medv, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2360873)

# %%
regr_2 = DecisionTreeRegressor(max_depth=8)
regr_2.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
plt.rc('figure', figsize=(20, 10))
tp = tree.plot_tree(regr_2, 
                    feature_names=x.columns.tolist(),  
                    filled=True)

# %% [markdown]
# ### 2.  Calcule o caminho indicado pelos CCP-alfas dessa árvore.

# %%
path = regr_2.cost_complexity_pruning_path(x_train, y_train)
path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 5.64971751e-05, 5.64971751e-05, 5.64971751e-05,
#         1.27118644e-04, 1.27118644e-04, 2.25988701e-04, 5.08474576e-04,
#         5.08474576e-04, 6.77966102e-04, 6.77966102e-04, 6.92090395e-04,
#         6.92090395e-04, 9.22787194e-04, 1.41242938e-03, 1.70903955e-03,
#         2.27871940e-03, 2.56355932e-03, 2.71186441e-03, 2.86016949e-03,
#         2.94256121e-03, 4.35263653e-03, 5.09887006e-03, 5.09887006e-03,
#         5.09887006e-03, 5.94296476e-03, 6.22881356e-03, 8.30508475e-03,
#         1.15348399e-02, 1.16101695e-02, 1.22760291e-02, 1.27118644e-02,
#         1.49320689e-02, 1.53813559e-02, 1.62711864e-02, 1.73022599e-02,
#         2.11362994e-02, 2.24109385e-02, 3.01318267e-02, 3.07350013e-02,
#         3.44348031e-02, 4.12212918e-02, 4.15869429e-02, 4.32245763e-02,
#         4.90739844e-02, 5.03677314e-02, 5.04343220e-02, 5.14695722e-02,
#         5.19926119e-02, 5.23600505e-02, 5.42570269e-02, 5.72881356e-02,
#         6.25241112e-02, 6.36909272e-02, 6.56427471e-02, 7.12014242e-02,
#         7.28000013e-02, 7.59369115e-02, 7.86450094e-02, 9.07933019e-02,
#         1.05561190e-01, 1.05791685e-01, 1.12834533e-01, 1.13905367e-01,
#         1.16647731e-01, 1.17334275e-01, 1.18136299e-01, 1.26960452e-01,
#         1.30626201e-01, 1.42542373e-01, 1.58776966e-01, 1.76001880e-01,
#         1.80839383e-01, 1.89183972e-01, 2.31653484e-01, 3.40914405e-01,
#         3.57575859e-01, 5.24759428e-01, 5.79823732e-01, 6.10328890e-01,
#         7.51940106e-01, 8.08358918e-01, 9.80846797e-01, 1.12982820e+00,
#         1.31859223e+00, 2.06826397e+00, 2.65181921e+00, 4.63489761e+00,
#         5.22367618e+00, 1.81426472e+01, 4.31249852e+01]),
#  'impurities': array([ 2.35645949,  2.35651599,  2.35657249,  2.35662898,  2.3567561 ,
#          2.35688322,  2.35710921,  2.35761768,  2.35812616,  2.35880413,
#          2.35948209,  2.36017418,  2.36086627,  2.36178906,  2.36320149,
#          2.36491053,  2.36718925,  2.36975281,  2.37246467,  2.37532484,
#          2.3782674 ,  2.38262004,  2.38771891,  2.39281778,  2.39791665,
#          2.40385961,  2.41008843,  2.41839351,  2.42992835,  2.45314869,
#          2.46542472,  2.47813658,  2.49306865,  2.50845001,  2.5247212 ,
#          2.54202346,  2.56315976,  2.58557069,  2.61570252,  2.64643752,
#          2.68087232,  2.72209362,  2.76368056,  2.80690514,  2.85597912,
#          2.90634685,  2.95678117,  3.05972032,  3.16370554,  3.21606559,
#          3.27032262,  3.32761075,  3.39013487,  3.45382579,  3.51946854,
#          3.66187139,  3.73467139,  3.8106083 ,  3.88925331,  3.98004661,
#          4.0856078 ,  4.29719117,  4.4100257 ,  4.52393107,  4.6405788 ,
#          4.75791308,  4.87604938,  5.00300983,  5.13363603,  5.2761784 ,
#          5.59373233,  5.76973421,  6.13141298,  6.50978092,  6.74143441,
#          7.08234881,  7.43992467,  7.9646841 ,  8.54450783,  9.15483672,
#          9.90677683, 12.33185358, 13.31270038, 14.44252858, 15.76112081,
#         17.82938477, 20.48120398, 25.11610159, 30.33977776, 48.48242498,
#         91.60741015])}

# %%
ccp_alphas, impurities = path.ccp_alphas, path.impurities

plt.figure(figsize=(10, 6))
plt.plot(ccp_alphas, impurities)
plt.xlabel("Alpha efetivo")
plt.ylabel("Impureza total das folhas")
# Out:
# Text(0, 0.5, 'Impureza total das folhas')

# %% [markdown]
# ### 3. Paca cada valor de alpha obtido no item 2, treine uma árvore com o respectivo alfa, e guarde essa árvore em uma lista.

# %%
clfs = []

for ccp_alpha in ccp_alphas:
    clf = DecisionTreeRegressor(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(x_train, y_train)
    clfs.append(clf)

# %%
tree_depths = [clf.tree_.max_depth for clf in clfs]
plt.figure(figsize=(10,  6))
plt.plot(ccp_alphas[:-1], tree_depths[:-1])
plt.xlabel("effective alpha")
plt.ylabel("Profundidade da árvore")
# Out:
# Text(0, 0.5, 'Profundidade da árvore')

# %% [markdown]
# ### 4. Para cada árvore na lista, calcule o MSE da árvore.

# %%
train_scores = [mean_squared_error(y_train , clf.predict(x_train)) for clf in clfs]
test_scores  = [mean_squared_error(y_test  , clf.predict(x_test )) for clf in clfs]

# %% [markdown]
# ### 5. Monte um gráfico do MSE pelo alpha, escolha um valor de alpha perto do ponto de mínimo do MSE

# %%
fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("MSE")
ax.set_title("MSE x alpha do conjunto de dados de treino e teste")
ax.plot(ccp_alphas[:-1], train_scores[:-1], marker='o', label="treino",
        drawstyle="steps-post")
ax.plot(ccp_alphas[:-1], test_scores[:-1], marker='o', label="teste",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# ### 6. Calcule o R-quadrado dessa árvore encontrada no item acima

# %%
arvore_final = DecisionTreeRegressor(random_state = 0, ccp_alpha = .25)
arvore_final.fit(x_train, y_train)
print(f'Profundidade: {arvore_final.tree_.max_depth}')
print(f"R-Quadrado na base de testes: {arvore_final.score(x_test, y_test):.2f}")
print(f'MSE na base de testes: {mean_squared_error(y_test, arvore_final.predict(x_test)):.2f}')
# Out:
# Profundidade: 8
# R-Quadrado na base de testes: 0.69
# MSE na base de testes: 20.79

# %% [markdown]
# ### 7. Visualize esta árvore.

# %%
plt.rc('figure', figsize=(10, 10))
tp = tree.plot_tree(arvore_final, feature_names=x.columns.tolist(), filled=True)
