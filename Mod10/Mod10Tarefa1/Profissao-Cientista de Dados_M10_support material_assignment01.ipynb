# %% [markdown]
# # Módulo 10 atividade 1

# %% [markdown]
# Uma instituição financeira quer conhecer melhor o perfil de renda de seus novos clientes para diversos fins, por exemplo, melhor dimensionar o limite de cartões de crédito dos novos clientes, sem necessariamente solicitar olerites ou documentações que impactem na experiência do seu cliente.
#
# Para isto, conduziu um estudo com alguns clientes, comprovando suas rendas através de olerites e outros documentos, e pretende construir um modelo preditivo para esta renda com base em algumas variáveis que já possui em seu banco de dados.
#
# As variáveis são intuitivas - note que há uma variável 'index' que é um identificador do cliente e que em geral o ```read_csv``` do pandas coloca também uma variável sequencial.
#
# Estes dados estão no arquivo ```previsao_de_renda.csv```. Carregue-o em um *dataframe*.
#
# 1) Avalie a estrutura de correlação das variáveis quantitativas através de um gráfico de "matriz de dispersão" e através da avaliação gráfica da matriz de correlações. Veja se você identifica algum padrão interessante ou que te faça sentido.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('previsao_de_renda.csv')
print(df.dtypes)
df
# Out:
# Unnamed: 0                 int64
# data_ref                  object
# index                      int64
# sexo                      object
# posse_de_veiculo            bool
# posse_de_imovel             bool
# qtd_filhos                 int64
# tipo_renda                object
# educacao                  object
# estado_civil              object
# tipo_residencia           object
# idade                      int64
# tempo_emprego            float64
# qt_pessoas_residencia    float64
# mau                         bool
# renda                    float64
# dtype: object
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
#        qtd_filhos        tipo_renda           educacao estado_civil  \
# 0               1       Assalariado         Secundário       Casado
# 1               0        Empresário         Secundário       Casado
# 2               2       Assalariado  Superior completo       Casado
# 3               0        Empresário         Secundário       Casado
# 4               0       Assalariado         Secundário       Casado
# ...           ...               ...                ...          ...
# 14995           1       Assalariado         Secundário       Casado
# 14996           1  Servidor público  Superior completo       Casado
# 14997           0       Assalariado         Secundário       Casado
# 14998           0  Servidor público  Superior completo       Casado
# 14999           0       Assalariado         Secundário       Casado
#
#       tipo_residencia  idade  tempo_emprego  qt_pessoas_residencia    mau  \
# 0                Casa     36       3.575342                    3.0  False
# 1                Casa     42       0.860274                    2.0  False
# 2                Casa     31       8.065753                    4.0  False
# 3                Casa     50       1.208219                    2.0  False
# 4                Casa     52      13.873973                    2.0  False
# ...               ...    ...            ...                    ...    ...
# 14995            Casa     37       2.046575                    3.0  False
# 14996         Estúdio     30      12.079452                    3.0  False
# 14997            Casa     40       2.161644                    2.0  False
# 14998            Casa     47       3.295890                    2.0  False
# 14999            Casa     50       3.049315                    2.0  False
#
#          renda
# 0      3369.24
# 1      6096.14
# 2      5658.98
# 3      7246.69
# 4      4017.37
# ...        ...
# 14995  1193.29
# 14996  2519.18
# 14997  1586.85
# 14998  6975.39
# 14999   993.86
#
# [15000 rows x 16 columns]

# %%
print(df.isna().sum())
df = df.dropna()
df
# Out:
# Unnamed: 0                  0
# data_ref                    0
# index                       0
# sexo                        0
# posse_de_veiculo            0
# posse_de_imovel             0
# qtd_filhos                  0
# tipo_renda                  0
# educacao                    0
# estado_civil                0
# tipo_residencia             0
# idade                       0
# tempo_emprego            2534
# qt_pessoas_residencia       0
# mau                         0
# renda                       0
# dtype: int64
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
#        qtd_filhos        tipo_renda           educacao estado_civil  \
# 0               1       Assalariado         Secundário       Casado
# 1               0        Empresário         Secundário       Casado
# 2               2       Assalariado  Superior completo       Casado
# 3               0        Empresário         Secundário       Casado
# 4               0       Assalariado         Secundário       Casado
# ...           ...               ...                ...          ...
# 14995           1       Assalariado         Secundário       Casado
# 14996           1  Servidor público  Superior completo       Casado
# 14997           0       Assalariado         Secundário       Casado
# 14998           0  Servidor público  Superior completo       Casado
# 14999           0       Assalariado         Secundário       Casado
#
#       tipo_residencia  idade  tempo_emprego  qt_pessoas_residencia    mau  \
# 0                Casa     36       3.575342                    3.0  False
# 1                Casa     42       0.860274                    2.0  False
# 2                Casa     31       8.065753                    4.0  False
# 3                Casa     50       1.208219                    2.0  False
# 4                Casa     52      13.873973                    2.0  False
# ...               ...    ...            ...                    ...    ...
# 14995            Casa     37       2.046575                    3.0  False
# 14996         Estúdio     30      12.079452                    3.0  False
# 14997            Casa     40       2.161644                    2.0  False
# 14998            Casa     47       3.295890                    2.0  False
# 14999            Casa     50       3.049315                    2.0  False
#
#          renda
# 0      3369.24
# 1      6096.14
# 2      5658.98
# 3      7246.69
# 4      4017.37
# ...        ...
# 14995  1193.29
# 14996  2519.18
# 14997  1586.85
# 14998  6975.39
# 14999   993.86
#
# [12466 rows x 16 columns]

# %%
df1 = df.drop(columns = ['Unnamed: 0', 'data_ref', 'index', 'sexo', 'estado_civil', 'qtd_filhos',
                         'tipo_residencia','educacao','tipo_renda'])
df[['posse_de_veiculo', 'posse_de_imovel']] = df[['posse_de_veiculo', 'posse_de_imovel']].astype(int)
print(df1.dtypes)
df1
# Out:
# posse_de_veiculo            bool
# posse_de_imovel             bool
# idade                      int64
# tempo_emprego            float64
# qt_pessoas_residencia    float64
# mau                         bool
# renda                    float64
# dtype: object
# C:\Users\mathe\AppData\Local\Temp\ipykernel_9248\3066076548.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['posse_de_veiculo', 'posse_de_imovel']] = df[['posse_de_veiculo', 'posse_de_imovel']].astype(int)
#        posse_de_veiculo  posse_de_imovel  idade  tempo_emprego  \
# 0                 False             True     36       3.575342
# 1                  True             True     42       0.860274
# 2                  True             True     31       8.065753
# 3                  True            False     50       1.208219
# 4                 False            False     52      13.873973
# ...                 ...              ...    ...            ...
# 14995              True             True     37       2.046575
# 14996              True             True     30      12.079452
# 14997              True             True     40       2.161644
# 14998             False             True     47       3.295890
# 14999              True             True     50       3.049315
#
#        qt_pessoas_residencia    mau    renda
# 0                        3.0  False  3369.24
# 1                        2.0  False  6096.14
# 2                        4.0  False  5658.98
# 3                        2.0  False  7246.69
# 4                        2.0  False  4017.37
# ...                      ...    ...      ...
# 14995                    3.0  False  1193.29
# 14996                    3.0  False  2519.18
# 14997                    2.0  False  1586.85
# 14998                    2.0  False  6975.39
# 14999                    2.0  False   993.86
#
# [12466 rows x 7 columns]

# %%
sns.pairplot(data = df1)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\mathe\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.regplot(x = 'renda', y = 'tempo_emprego', data = df1)
plt.title('Tempo de emprego x Renda')
plt.xlabel('Renda')
plt.ylabel('Tempo de emprego')
# Out:
# Text(0, 0.5, 'Tempo de emprego')

# %%
sns.regplot(x = 'renda', y = 'mau', data = df1)
plt.title('Mau pagador x Renda')
plt.xlabel('Renda')
plt.ylabel('Mau pagador')
# Out:
# Text(0, 0.5, 'Mau pagador')

# %%
sns.regplot(x='tempo_emprego', y='mau', data = df1)
plt.title('Mau pagador x tempo de emprego')
plt.xlabel('tempo de emprego')
plt.ylabel('Mau pagador')
# Out:
# Text(0, 0.5, 'Mau pagador')

# %%
cmap = sns.diverging_palette(h_neg=125, h_pos=350, s=90, l=50, as_cmap=True, sep = 5, center = 'light')

sns. clustermap(df1.corr(), figsize=(10,10), center = 0, cmap=cmap)

# %% [markdown]
# ## insights:
# - Clientes com mais tempo de emprego tendem a possuir mais renda
# - Quanto maior a renda menor as chances do cliente ser mau pagador
# - Clientes depois de um certo tempo de emprego o número dos clientes inadimplentes tende a diminuir.
# - clientes que possuem mais tempo de emprego tendem a terem menos chance de ser maus pagadores

# %% [markdown]
# 2) Avalie um gráfico de dispersão (*scatterplot*) específico para as duas variáveis mais correlacionadas com *renda*.

# %%
sns.regplot(x = 'renda', y = 'tempo_emprego', data = df1, 
            scatter_kws={"color": "grey"}, line_kws={"color": 'lightgreen'})
plt.title('Renda x tempo de emprego')
plt.xlabel('Renda')
plt.ylabel('tempo de emprego')
df1[["renda","tempo_emprego"]].corr()
# Out:
#                   renda  tempo_emprego
# renda          1.000000       0.394235
# tempo_emprego  0.394235       1.000000

# %%
sns.regplot(x = 'renda', y = 'idade', data = df1,
           scatter_kws={"color": "grey"}, line_kws={"color": 'lightgreen'})
plt.title('Renda x Idade')
plt.xlabel('Renda')
plt.ylabel('Idade')
df1[["renda","idade"]].corr()
# Out:
#           renda     idade
# renda  1.000000  0.151364
# idade  0.151364  1.000000

# %%
sns.regplot(x = 'idade', y = 'tempo_emprego', data = df1, 
            scatter_kws={"color": "grey"}, line_kws={"color": 'lightgreen'})
plt.title('Idade x tempo de emprego')
plt.xlabel('Idade')
plt.ylabel('tempo de emprego')
df1[["idade","tempo_emprego"]].corr()
# Out:
#                   idade  tempo_emprego
# idade          1.000000       0.323934
# tempo_emprego  0.323934       1.000000

# %% [markdown]
# 3) Na su aopinião, há outliers na variável renda?

# %%
df1.renda.describe()
# Out:
# count    12466.000000
# mean      4850.045256
# std       4873.182512
# min        159.900000
# 25%       2026.390000
# 50%       3422.440000
# 75%       5916.970000
# max      89918.040000
# Name: renda, dtype: float64

# %%
df.renda.median()
# Out:
# 3422.44

# %%
df.renda.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Insight:
# Após analisarmos o gráfico de boxplot, verificamos a presença de outliers. No entanto, seria necessário avaliar mais profundamente o caso para determinar se esses outliers são resultado de erros de digitação, medição ou outros fatores. Caso sejam considerados válidos, sua exclusão pode distorcer as conclusões da análise.

# %% [markdown]
# 4) Calcule o logaritmo da variável renda e repita a sequência de análise

# %%
df1_log = df1
df1_log['log_renda'] = np.log(df1_log['renda'])
sns.regplot(x = 'tempo_emprego', y='log_renda', data = df1_log,
                  scatter_kws={"color": "grey"}, line_kws={"color": 'lightgreen'})
plt.title('LOG da Renda x tempo de emprego')
plt.xlabel('tempo de emprego')
plt.ylabel('LOG da Renda')
print(df1_log[['renda','tempo_emprego','log_renda', 'idade']].corr())
# Out:
#                   renda  tempo_emprego  log_renda     idade
# renda          1.000000       0.394235   0.836656  0.151364
# tempo_emprego  0.394235       1.000000   0.379556  0.323934
# log_renda      0.836656       0.379556   1.000000  0.145638
# idade          0.151364       0.323934   0.145638  1.000000

# %%
df1_log.corr()
# Out:
#                        posse_de_veiculo  posse_de_imovel     idade  \
# posse_de_veiculo               1.000000         0.003308 -0.090136
# posse_de_imovel                0.003308         1.000000  0.081715
# idade                         -0.090136         0.081715  1.000000
# tempo_emprego                 -0.087514         0.000112  0.323934
# qt_pessoas_residencia          0.122773         0.015852 -0.257281
# mau                           -0.013536        -0.016710 -0.016428
# renda                          0.040626         0.040138  0.151364
# log_renda                      0.069070         0.056859  0.145638
#
#                        tempo_emprego  qt_pessoas_residencia       mau  \
# posse_de_veiculo           -0.087514               0.122773 -0.013536
# posse_de_imovel             0.000112               0.015852 -0.016710
# idade                       0.323934              -0.257281 -0.016428
# tempo_emprego               1.000000              -0.065748 -0.047722
# qt_pessoas_residencia      -0.065748               1.000000  0.003058
# mau                        -0.047722               0.003058  1.000000
# renda                       0.394235              -0.004865 -0.014952
# log_renda                   0.379556               0.008412 -0.019304
#
#                           renda  log_renda
# posse_de_veiculo       0.040626   0.069070
# posse_de_imovel        0.040138   0.056859
# idade                  0.151364   0.145638
# tempo_emprego          0.394235   0.379556
# qt_pessoas_residencia -0.004865   0.008412
# mau                   -0.014952  -0.019304
# renda                  1.000000   0.836656
# log_renda              0.836656   1.000000

# %% [markdown]
# 5) A aplicação do LOG você acha que melhorou ou piorou a análise?

# %% [markdown]
# Facilitou, a aplicação do LOG permitiu visualizar mais clara a distribuição da renda. Destacando a presença de pessoas com rendimentos muito acima da média
